# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
# %matplotlib inline

# %%
dataset_z_score = pd.read_csv('../data/diabetes_min_max.csv')
dataset_min_max = pd.read_csv('../data/diabetes_min_max.csv')

# %%
dataset_min_max
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.352941  0.670968       0.489796       0.304348  0.079086  0.314928
# 1       0.058824  0.264516       0.428571       0.239130  0.079086  0.171779
# 2       0.470588  0.896774       0.408163       0.147135  0.079086  0.104294
# 3       0.058824  0.290323       0.428571       0.173913  0.096154  0.202454
# 4       0.000000  0.600000       0.163265       0.304348  0.185096  0.509202
# ..           ...       ...            ...            ...       ...       ...
# 763     0.588235  0.367742       0.530612       0.445652  0.199519  0.300613
# 764     0.117647  0.503226       0.469388       0.217391  0.079086  0.380368
# 765     0.294118  0.496774       0.489796       0.173913  0.117788  0.163599
# 766     0.058824  0.529032       0.367347       0.147135  0.079086  0.243354
# 767     0.058824  0.316129       0.469388       0.260870  0.079086  0.249489
#
#      DiabetesPedigreeFunction       Age  Outcome
# 0                    0.234415  0.483333        1
# 1                    0.116567  0.166667        0
# 2                    0.253629  0.183333        1
# 3                    0.038002  0.000000        0
# 4                    0.943638  0.200000        1
# ..                        ...       ...      ...
# 763                  0.039710  0.700000        0
# 764                  0.111870  0.100000        0
# 765                  0.071307  0.150000        0
# 766                  0.115713  0.433333        1
# 767                  0.101196  0.033333        0
#
# [768 rows x 9 columns]

# %%
dataset_z_score.shape
# Out:
# (768, 9)

# %%
def train_test_holdout_split(data, test_data_ratio, holdout_data_ratio):
    rows, _ = data.shape
    test_data_size = int(test_data_ratio * rows)
    holdout_data_size = int(holdout_data_ratio * rows)
    
    data = data.sample(frac=1)
    
    test_data = data[:test_data_size]
    holdout_data = data[test_data_size:holdout_data_size + test_data_size]
    train_data = data[holdout_data_size + test_data_size:]
    
    return (train_data, test_data, holdout_data)

# %%
train_data, test_data, holdout_data = train_test_holdout_split(dataset_z_score, 0.2, 0.1)

# %%
holdout_data
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 273     0.058824  0.174194       0.551020       0.467391  0.037260  0.306748
# 484     0.000000  0.651613       0.460260       0.147135  0.079086  0.531697
# 456     0.058824  0.587097       0.306122       0.147135  0.079086  0.173824
# 290     0.000000  0.219355       0.653061       0.239130  0.031250  0.382413
# 458     0.588235  0.670968       0.612245       0.445652  0.268029  0.396728
# ..           ...       ...            ...            ...       ...       ...
# 682     0.000000  0.329032       0.408163       0.347826  0.109375  0.539877
# 716     0.176471  0.832258       0.551020       0.347826  0.205529  0.319018
# 751     0.058824  0.496774       0.551020       0.347826  0.072115  0.425358
# 694     0.117647  0.296774       0.367347       0.147135  0.079086  0.108384
# 107     0.235294  0.645161       0.346939       0.228261  0.151442  0.231084
#
#      DiabetesPedigreeFunction       Age  Outcome
# 273                  0.146883  0.000000        0
# 484                  0.235696  0.166667        1
# 456                  0.260034  0.683333        0
# 290                  0.152007  0.000000        0
# 458                  0.394108  0.500000        1
# ..                        ...       ...      ...
# 682                  0.122972  0.016667        0
# 716                  0.380871  0.166667        1
# 751                  0.078138  0.116667        0
# 694                  0.048249  0.066667        0
# 107                  0.089240  0.266667        0
#
# [76 rows x 9 columns]
